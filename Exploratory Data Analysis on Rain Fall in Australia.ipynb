# %% [markdown]
# # Author Bakki Akhil
# # Exploratory Data Analysis on Rain Fall in Australia

# %% [markdown]
# # Here we have taken the dataset of Rain Fall in Australia from secondary platform named as Kaggle for analysing
# # Below are the few steps performed for analysing

# %% [markdown]
# # Below we are Importing required libraries for performing analysis

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Description: Here we are describing all the columns present in the dataset
# ### Date: The date of observation
# ### Location: The common name of the location of the weather station having 49 Locations
# ### Temprature: The (maximum & Minimum) temperature in degrees celsius
# ### Rainfall: The amount of rainfall recorded for the day in mm
# ### Evaporation: The so-called Class A pan evaporation (mm) in the 24 hours to 9am
# ### Sunshine: The number of hours of bright sunshine in the day
# ### WindGustDir: The direction of the strongest wind gust in the 24 hours to midnight
# ### WindGustSpeed:The speed (km/h) of the strongest wind gust in the 24 hours to midnight
# ### WindDir9am: Direction of the wind at 9am
# ### WindDir3pm: Direction of the wind at 3pm
# ### WindSpeed9am: Wind speed (km/hr) averaged over 10 minutes prior to 9am
# ### WindSpeed3pm: Wind speed (km/hr) averaged over 10 minutes prior to 3pm
# ### Humidity9am: Humidity (percent) at 9am
# ### Humidity3pm: Humidity (percent) at 3pm
# ### Pressure9am: Atmospheric pressure (hpa) reduced to mean sea level at 9am
# ### Pressure3pm: Atmospheric pressure (hpa) reduced to mean sea level at 3pm
# ### Cloud9am: Fraction of sky obscured by cloud at 9am. This is measured in "oktas", which are a unit of eigths. It records how many
# ### Cloud3pm: Fraction of sky obscured by cloud (in "oktas": eighths) at 3pm. See Cload9am for a description of the values
# ### Temp9am: Temperature (degrees C) at 9am
# ### Temp3pm: Temperature (degrees C) at 3pm
# ### RainToday: Boolean: 1 if precipitation (mm) in the 24 hours to 9am exceeds 1mm, otherwise 0
# ### RainTomorrow: The amount of next day rain in mm. Used to create response variable RainTomorrow. A kind of measure of the "risk"

# %% [markdown]
# # Below we are importing the dataset

# %%
# Importing the data using pandas
df = pd.read_csv("D:\\Akhil MBA\\MBA 4 Trimester\\Data Exploration and Application using Python\\CIA 2\\weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# The below output shows that there are 1,45,460 rows with 23 columns
df.shape
# Out:
# (145460, 23)

# %%
# Here the output shows the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# Below output shows the sum of null values present in each column in the dataset
# form this we can say that there are few variables like Evaporation, Sunshine, Cloud9am, Cloud3pm having approximately 50% of null values in the dataset
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # Below we are checking the presence of "Duplicate values" in the dataset

# %%
# From the outpu we can say that there are no duplicate values in the dataset
df.duplicated().sum()
# Out:
# 0

# %%
# Visualizing the null values using Heat Map
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(),cmap='winter',yticklabels=False,cbar=False)
plt.show()

# %% [markdown]
# # Data Cleaning and processing
# # Below we are removing unwanted columns from the dataset which has less preference in interpreting

# %%
# Here we are removing Date column from the dataset as it doesnt play much role in interpreting
df.drop(['Date'],axis=1,inplace=True)

# %%
# Below we are checking the outlier presence in the column Rainfall
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df,x=df.Rainfall, orient="h")
# Out:
# <AxesSubplot:xlabel='Rainfall'>

# %%
# Here we can see that the Evaporation, Sunshine columns have all (3040) null values 
dfAlb = df[df['Location']=='Albury']
dfAlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3040 entries, 0 to 3039
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       3040 non-null   object
#  1   MinTemp        3029 non-null   float64
#  2   MaxTemp        3029 non-null   float64
#  3   Rainfall       3011 non-null   float64
#  4   Evaporation    0 non-null      float64
#  5   Sunshine       0 non-null      float64
#  6   WindGustDir    3008 non-null   object
#  7   WindGustSpeed  3008 non-null   float64
#  8   WindDir9am     2515 non-null   object
#  9   WindDir3pm     2994 non-null   object
#  10  WindSpeed9am   3031 non-null   float64
#  11  WindSpeed3pm   3029 non-null   float64
#  12  Humidity9am    3031 non-null   float64
#  13  Humidity3pm    3032 non-null   float64
#  14  Pressure9am    3035 non-null   float64
#  15  Pressure3pm    3032 non-null   float64
#  16  Cloud9am       1289 non-null   float64
# ...

# %%
# Here we can see that the Evaporation, Sunshine columns have all (3009) null values 
dfBa = df[df['Location']=='BadgerysCreek']
dfBa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3009 entries, 3040 to 6048
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       3009 non-null   object
#  1   MinTemp        2973 non-null   float64
#  2   MaxTemp        2980 non-null   float64
#  3   Rainfall       2928 non-null   float64
#  4   Evaporation    0 non-null      float64
#  5   Sunshine       0 non-null      float64
#  6   WindGustDir    2933 non-null   object
#  7   WindGustSpeed  2933 non-null   float64
#  8   WindDir9am     2574 non-null   object
#  9   WindDir3pm     2924 non-null   object
#  10  WindSpeed9am   2960 non-null   float64
#  11  WindSpeed3pm   2961 non-null   float64
#  12  Humidity9am    2955 non-null   float64
#  13  Humidity3pm    2954 non-null   float64
#  14  Pressure9am    2841 non-null   float64
#  15  Pressure3pm    2836 non-null   float64
#  16  Cloud9am       0 non-null      float64
# ...

# %%
# Here we can see that the Evaporation, Sunshine columns have all (207) null values 
dfCo = df[df['Location']=='Cobar']
dfCo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3009 entries, 6049 to 9057
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       3009 non-null   object
#  1   MinTemp        3003 non-null   float64
#  2   MaxTemp        3006 non-null   float64
#  3   Rainfall       2988 non-null   float64
#  4   Evaporation    2666 non-null   float64
#  5   Sunshine       550 non-null    float64
#  6   WindGustDir    2967 non-null   object
#  7   WindGustSpeed  2967 non-null   float64
#  8   WindDir9am     2982 non-null   object
#  9   WindDir3pm     2994 non-null   object
#  10  WindSpeed9am   2992 non-null   float64
#  11  WindSpeed3pm   2997 non-null   float64
#  12  Humidity9am    2884 non-null   float64
#  13  Humidity3pm    2884 non-null   float64
#  14  Pressure9am    2979 non-null   float64
#  15  Pressure3pm    2983 non-null   float64
#  16  Cloud9am       2629 non-null   float64
# ...

# %% [markdown]
# # Below we are replacing the null values in the dataset
# # Here for categorical columns we are filling the empty values with its corresponding previous values
# # Here for Numerical columns we are filling the empty values with its median value
# # The reason for using median for filling null values is that there is great amount of presence of null values with many outliers in the dataset omiting it leads to removal of some crucial information. Replacing it with mean leads to the skewness in the values. So, taking these conditions into consideration we have replaced these null values with median values

# %%
#Filling numerical empty column with median value of that row 
#And for categorical filling empty values with its corresponding previous value

def fill_na(info):
    cols=info.columns
    for col in cols:
        if info[col].dtype=='object':
            info[col].fillna(method='ffill',inplace=True)
        else:
            info[col].fillna(info[col].median(),inplace=True)
    return info

# %%
# Creating a new dataframe after removing all the null values
df1=fill_na(df)

# %%
# Checking the null values in the new dataframe
# As the output shows that there are no null values in the dataset
plt.figure(figsize=(10,6))
sns.heatmap(df1.isnull(),cmap='winter',yticklabels=False,cbar=False)
plt.show()

# %%
# Checking the shape of the new dataframe
df1.shape
# Out:
# (145460, 22)

# %%
# Checking the top 5 rows of the new dataframe
df1.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          4.8       8.4           W
# 1   Albury      7.4     25.1       0.0          4.8       8.4         WNW
# 2   Albury     12.9     25.7       0.0          4.8       8.4         WSW
# 3   Albury      9.2     28.0       0.0          4.8       8.4          NE
# 4   Albury     17.5     32.3       1.0          4.8       8.4           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           44.0          W        WNW  ...         71.0         22.0
# 1           44.0        NNW        WSW  ...         44.0         25.0
# 2           46.0          W        WSW  ...         38.0         30.0
# 3           24.0         SE          E  ...         45.0         16.0
# 4           41.0        ENE         NW  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        145460 non-null  float64
#  2   MaxTemp        145460 non-null  float64
#  3   Rainfall       145460 non-null  float64
#  4   Evaporation    145460 non-null  float64
#  5   Sunshine       145460 non-null  float64
#  6   WindGustDir    145460 non-null  object
#  7   WindGustSpeed  145460 non-null  float64
#  8   WindDir9am     145460 non-null  object
#  9   WindDir3pm     145460 non-null  object
#  10  WindSpeed9am   145460 non-null  float64
#  11  WindSpeed3pm   145460 non-null  float64
#  12  Humidity9am    145460 non-null  float64
#  13  Humidity3pm    145460 non-null  float64
#  14  Pressure9am    145460 non-null  float64
#  15  Pressure3pm    145460 non-null  float64
# ...

# %% [markdown]
# # Data Visualization
# # Below we are visualizing all the variables present in the dataframe

# %%
# Below we are plotting all the variables
plt.figure(figsize=(25,30))
plt.subplot(6,2,1)
sns.histplot(df1,x='MinTemp')
plt.subplot(6,2,2)
sns.histplot(df1,x='MaxTemp')
plt.subplot(6,2,3)
sns.histplot(df1,x='WindGustSpeed')
plt.subplot(6,2,4)
sns.histplot(df1,x='WindSpeed9am')
plt.subplot(6,2,5)
sns.histplot(df1,x='WindSpeed3pm')
plt.subplot(6,2,6)
sns.histplot(df1,x='Humidity9am')
plt.subplot(6,2,7)
sns.histplot(df1,x='Humidity3pm')
plt.subplot(6,2,8)
sns.histplot(df1,x='Pressure9am')
plt.subplot(6,2,9)
sns.histplot(df1,x='Pressure3pm')
plt.subplot(6,2,10)
sns.histplot(df1,x='Temp9am')
plt.subplot(6,2,11)
sns.histplot(df1,x='Temp3pm')
plt.show()

# %%
# Ploting the Evaporation 
fig,ax=plt.subplots(figsize=(15,6))
sns.distplot(df1.Evaporation)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Evaporation', ylabel='Density'>

# %%
# Ploting the Sunshine 
fig,ax=plt.subplots(figsize=(15,6))
sns.distplot(df1.Sunshine)
# Out:
# C:\Users\Akhil\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sunshine', ylabel='Density'>

# %%
# Plotting cloud 9am and cloud 3pm
plt.figure(figsize=(30,25))
plt.subplot(2,1,1)
sns.histplot(df1, x='Cloud9am')
plt.subplot(2,1,2)
sns.histplot(df1, x='Cloud3pm')
# Out:
# <AxesSubplot:xlabel='Cloud3pm', ylabel='Count'>

# %%
# Plotting wind direction
plt.figure(figsize=(25,20))
plt.subplot(3,2,1)
sns.countplot(data = df1,x=df1['WindGustDir'])
plt.subplot(3,2,2)
sns.countplot(data = df1,x=df1['WindDir9am'])
plt.subplot(3,2,3)
sns.countplot(data = df1,x = df1['WindDir3pm'])
plt.show()

# %%
# PLotting the occurrence of rainfall
plt.figure(figsize=(25,20))
plt.subplot(2,1,1)
sns.countplot(data = df1,x=df1['RainToday'])
plt.subplot(2,1,2)
sns.countplot(data = df1,x=df1['RainTomorrow'])
plt.show()

# %%
# Plotting the Location
fig, ax = plt.subplots(figsize= (20,20))
sns.countplot(data = df1,y = df1['Location'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location'>

# %%
# Below heat map shows the relationship between all the variables present in the dataframe
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Checking for the presence of Outliers

# %%
# Outlier check in Minimum temperature
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.MinTemp, orient="h")
# Out:
# <AxesSubplot:xlabel='MinTemp'>

# %%
# Outlier check in Maximum temperature
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.MaxTemp, orient="h")
# Out:
# <AxesSubplot:xlabel='MaxTemp'>

# %%
# Outlier check in Rainfall
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Rainfall, orient="h")
# Out:
# <AxesSubplot:xlabel='Rainfall'>

# %%
# Outlier check in Evaporation
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Evaporation, orient="h")
# Out:
# <AxesSubplot:xlabel='Evaporation'>

# %%
# Outlier check in Sunshine
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Sunshine, orient="h")
# Out:
# <AxesSubplot:xlabel='Sunshine'>

# %%
# Outlier check in direction of strong wind
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.WindGustSpeed, orient="h")
# Out:
# <AxesSubplot:xlabel='WindGustSpeed'>

# %%
# Outlier check in Wind speed at 9am
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.WindSpeed9am, orient="h")
# Out:
# <AxesSubplot:xlabel='WindSpeed9am'>

# %%
# Outlier check in Wind speed at 3pm
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.WindSpeed3pm, orient="h")
# Out:
# <AxesSubplot:xlabel='WindSpeed3pm'>

# %%
# Outlier check in Humidity at 9am
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Humidity9am, orient="h")
# Out:
# <AxesSubplot:xlabel='Humidity9am'>

# %%
# Outlier check in Humidity at 3pm
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Humidity3pm, orient="h")
# Out:
# <AxesSubplot:xlabel='Humidity3pm'>

# %%
# Outlier check in Pressure at 9am
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Pressure9am, orient="h")
# Out:
# <AxesSubplot:xlabel='Pressure9am'>

# %%
# Outlier check in Pressure at 3pm
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Pressure3pm, orient="h")
# Out:
# <AxesSubplot:xlabel='Pressure3pm'>

# %%
# Outlier check in Cloud at 9am
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Cloud9am, orient="h")
# Out:
# <AxesSubplot:xlabel='Cloud9am'>

# %%
# Outlier check in Cloud at 3pm
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Cloud3pm, orient="h")
# Out:
# <AxesSubplot:xlabel='Cloud3pm'>

# %%
# Outlier check in Temperature at 9am
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Temp9am, orient="h")
# Out:
# <AxesSubplot:xlabel='Temp9am'>

# %%
# Outlier check in Temperature at 3pm
fig, ax = plt.subplots(figsize = (15,5))
sns.boxplot(data=df1,x=df1.Temp3pm, orient="h")
# Out:
# <AxesSubplot:xlabel='Temp3pm'>

# %%
# Plotting a voilin plots of variables
plt.figure(figsize=(30,40))
plt.subplot(16,2,1)
sns.violinplot(data= df1, x=df1.MinTemp, orient='h')
plt.subplot(16,2,2)
sns.violinplot(data= df1, x=df1.MaxTemp, orient='h')
plt.subplot(16,2,3)
sns.violinplot(data= df1, x=df1.Rainfall, orient='h')
plt.subplot(16,2,4)
sns.violinplot(data= df1, x=df1.Evaporation, orient='h')
plt.subplot(16,2,5)
sns.violinplot(data= df1, x=df1.Sunshine, orient='h')
plt.subplot(16,2,6)
sns.violinplot(data= df1, x=df1.WindGustSpeed, orient='h')
plt.subplot(16,2,7)
sns.violinplot(data= df1, x=df1.WindSpeed9am, orient='h')
plt.subplot(16,2,8)
sns.violinplot(data= df1, x=df1.WindSpeed3pm, orient='h')
plt.subplot(16,2,9)
sns.violinplot(data= df1, x=df1.Humidity9am, orient='h')
plt.subplot(16,2,10)
sns.violinplot(data= df1, x=df1.Humidity3pm, orient='h')
plt.subplot(16,2,11)
sns.violinplot(data= df1, x=df1.Pressure9am, orient='h')
plt.subplot(16,2,12)
sns.violinplot(data= df1, x=df1.Pressure3pm, orient='h')
plt.subplot(16,2,13)
sns.violinplot(data= df1, x=df1.Cloud9am, orient='h')
plt.subplot(16,2,14)
sns.violinplot(data= df1, x=df1.Cloud3pm, orient='h')
plt.subplot(16,2,15)
sns.violinplot(data= df1, x=df1.Temp9am, orient='h')
plt.subplot(16,2,16)
sns.violinplot(data= df1, x=df1.Temp3pm, orient='h')
# Out:
# <AxesSubplot:xlabel='Temp3pm'>

# %%
# Below we are plotting the relationship between two variables
plt.figure(figsize=(15,15))
plt.subplot(3,2,1)
sns.scatterplot(data=df1, x="MinTemp", y="MaxTemp")
plt.subplot(3,2,2)
sns.scatterplot(data=df1,  x="WindSpeed9am", y="WindSpeed3pm")
plt.subplot(3,2,3)
sns.scatterplot(data=df1, x="Humidity9am", y="Humidity3pm")
plt.subplot(3,2,4)
sns.scatterplot(data=df1, x="Pressure9am", y="Pressure3pm")
plt.subplot(3,2,5)
sns.scatterplot(data=df1, x="Cloud9am", y="Cloud3pm")
plt.subplot(3,2,6)
sns.scatterplot(data=df1, x="Temp9am", y="Temp3pm")
plt.show()

# %% [markdown]
# # Objectives to be analysed using EDA
# # 1. FInding the relationship between Rainfall, Evaporation, Sunshine.
# # 2. Finding the effect of wind direction in different location with Maximum temperature.
# # 3. Finding the effect of wind direction in different location with Minimum temperature.
# # 4. Finding the effect of rainfall on today's rain.
# # 5. Finding the effect of rainfall on tomorrows rain.

# %%
# Objective-1
# Here our main objective to find the relationship between Rainfall, Evaporation, Sunshine
# The output here shows that there is less linear relation
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.scatterplot(data=df1,  x="Rainfall", y="Evaporation")
plt.subplot(2,2,2)
sns.scatterplot(data=df1, x="Evaporation", y="Sunshine")
plt.show()

# %%
# Objective-2
# Objective here is to find the effect of Maximum Temperature and Wind direction on various locations
plt.figure(figsize=(15,15))
sns.scatterplot(data=df1,  x="MaxTemp", y="Location", hue="WindGustDir")
plt.show()

# %%
# Objective-3
# Objective here is to find the effect of Minimum Temperature and Wind direction on various locations
plt.figure(figsize=(15,15))
sns.scatterplot(data=df1,  x="MinTemp", y="Location", hue="WindGustDir")
plt.show()

# %%
# Objective-4
# Form below output we can esstimate the effect of rainfall on todays rain 
plt.figure(figsize=(15,5))
sns.scatterplot(data=df1,  x="RainToday", y="Rainfall", hue = 'Evaporation')
plt.show()

# %%
# Objective-5
# From below output we can esstimate the effect of rain fall on tomorrows rain
plt.figure(figsize=(15,5))
sns.scatterplot(data=df1,  x="RainTomorrow", y="Rainfall", hue = 'Evaporation')
plt.show()

# %% [markdown]
# # Conclusion
# # Here we can observe occurance of rain fall in Australia containing 1,45,460 rows with 23 columns. By taking all these variables into consideration we were able to predict the occurance of rainfall. The dataset here is filled with many null values but the null values are replaced properly.
# # From the above analysis we were able to analyse the effect of wind direction in different Locations in Australia with respective to Minimum and Maximum temperatures.
# # We were able to find the relation between Rainfall, Evapouration and sunshine we can observe that there no linear relation between them. This may occur as we have filled the null values in these columns with median values. If we have provided with proper data with less null values in these columns we will be able to find the exact relationship between the variables in these columns in Australia.
# # We have also explored in occurance of rainfall today with respective to rainfall and evaporation. Here we have observed that there is a high chance of rainfall with the evapouration.
# # We have also explored in occurance of rainfall tomorrow with respective to rainfall and evaporation. Here we have occurance of rain is slightly higher than not raining tomorrow.

# %% [markdown]
# # Recommendations: Few recommendations that can be provided from above analysis are as follows
# # 1. People in Australia should equip themselves with basic needs like rain-jacket, raincoat and umbrella to avoid cold due to rain.
# # 2. There may be raise in power cuts in few areas like Uluru, Katherine, Cairns and many more which may raise either due to heavy rain or due to heavy wind. So people in these area may keep a backup.
# # 3. We can also observe that with increase in Sunshine there is also an increase in Evaporation which may also lead to rain in some areas. So, people in those areas must try to stay connected with their family or friends to keep informed about your whereabouts in extreme conditions.
# # 4. We have also observed that there is a high chance of rainfall today and tomorrow in relation with evaporation. People in these areas are suggested to have a proper medications in hand.
# # 5.  From analysis we can recommend people in Australia to have a healthy diet and to drink water. As we normally not feel like to drink water or eat much during monsoon season leading to reduction of immune system and may also lead to dehydration. Dirnking more water and having proper diet results in maintaining immune system. So, people in Australia are recommended to drink more water and have a proper diet.
